# %%
# Network structure answers based on the COVID symptom diagram

direct_predictors_covid = [
    "Fever",
    "Wheezing",
    "Loss of Taste",
    "Loss of Smell",
    "Loss of Appetite"
]

markov_blanket_fever = {
    "Parents": [
        "Muscle Aches",
        "Runny Nose",
        "Loss of Taste"
    ],
    "Child": [
        "COVID-19 Test Result"
    ],
    "Co-Parents": [
        "Wheezing",
        "Loss of Appetite",
        "Loss of Smell",
        "Loss of Taste"
    ]
}

indirect_predictors_covid = [
    "Runny Nose",
    "Muscle Aches",
    "Fatigue"
]

print("Direct predictors of COVID test result:")
for item in direct_predictors_covid:
    print("-", item)

print("\nNumber of direct predictors of COVID:")
print(len(direct_predictors_covid))

print("\nMarkov blanket of fever:")
for category, variables in markov_blanket_fever.items():
    print(category + ":")
    for var in variables:
        print("-", var)

print("\nIndirect predictors of COVID:")
for item in indirect_predictors_covid:
    print("-", item)

print("\nMost important mediator:")
print("Fever")

print("\nEquation for fever:")
print("logit(P(Fever)) = a + b1(Age>30) + b2(Female) + b3(MuscleAches) + b4(RunnyNose) + b5(LossOfTaste) + b6(LossOfAppetite)")
# Out:
# Direct predictors of COVID test result:
# - Fever
# - Wheezing
# - Loss of Taste
# - Loss of Smell
# - Loss of Appetite
#
# Number of direct predictors of COVID:
# 5
#
# Markov blanket of fever:
# Parents:
# - Muscle Aches
# - Runny Nose
# - Loss of Taste
# Child:
# - COVID-19 Test Result
# Co-Parents:
# - Wheezing
# - Loss of Appetite
# - Loss of Smell
# - Loss of Taste
#
# Indirect predictors of COVID:
# - Runny Nose
# - Muscle Aches
# - Fatigue
#
# Most important mediator:
# Fever
#
# Equation for fever:
# logit(P(Fever)) = a + b1(Age>30) + b2(Female) + b3(MuscleAches) + b4(RunnyNose) + b5(LossOfTaste) + b6(LossOfAppetite)
